# %% [markdown]
# - Evrensel kısaltmaları kullanarak numpy ve pandas kütüphanelerini import ediniz.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1) İndexlerinde "Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men"  , "Captain America"  , "Disaster Movie" olan
#    Datasında 9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1 olan bir seri oluşturun.(2 Farklı yolla da oluşturun) (Datayı ve İndexleri liste olarak göndererek ve doğrudan dictionary göndererek.)

# %%
my_series1 = ["Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men"  , "Captain America"  , "Disaster Movie"]
my_data1 = [9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1]

# %%
pd.Series(data = my_data1, index = my_series1)
# Out:
# Breaking Bad        9.4
# Chernobyl           9.3
# Leyla ile Mecnun    8.8
# X-Men               8.4
# Captain America     3.8
# Disaster Movie      2.1
# dtype: float64

# %%
my_dict1 = {"Breaking Bad": 9.4 , "Chernobyl" : 9.3 , "Leyla ile Mecnun" : 8.8 , "X-Men" : 8.4 , "Captain America" : 3.8  , "Disaster Movie" : 2.1}

# %%
pd.Series(data = my_dict1)
# Out:
# Breaking Bad        9.4
# Chernobyl           9.3
# Leyla ile Mecnun    8.8
# X-Men               8.4
# Captain America     3.8
# Disaster Movie      2.1
# dtype: float64

# %% [markdown]
# 2) donem1_mat adında bir seri oluşturun. Bu serinin içinde "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" index değerleri olsun,
#    85, 80 , 94 , 74 , 91 , 96 , 70 data değerleri olsun. Bu şekilde donem1 adında öğrencilerin 1.dönem matematik nor ortalamalarının tutulduğu bir seri oluşturun.
#
#    donem2_mat adında başka bir seri oluşturun. Okula yeni bir öğrenci gelmiş olsun ve indexlerde bu sefer "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert"         indexleri olsun. 80, 92 , 85 , 87, 90 , 92, 100, 83 ise dataları olsun. Bu iki seriyi birleştirerek bütün öğrencilerin yıl sonu matematik ORTALAMASINI hesaplayın.
#
#    Not : Eğer bir öğrencinin sadece ikinci dönem notu bulunuyorsa, birinci dönem hesaba eklenmeden ikinci dönem notu yıl sonu notu olarak hesaplansın.

# %%
donem1_mat = pd.Series([85, 80, 94, 74, 91, 96, 70], index=["Ali", "Deniz", "Aslı", "Burak", "Kerem", "Yasemin", "Derya"])
donem2_mat = pd.Series([80, 92, 85, 87, 90, 92, 100, 83], index=["Ali", "Deniz", "Aslı", "Burak", "Kerem", "Yasemin", "Derya", "Mert"])

# %%
yilsonu_notlari = []
for ogrenci in donem2_mat.index:

    if ogrenci in donem1_mat.index:
        yilsonu_notu = (donem1_mat[ogrenci] + donem2_mat[ogrenci]) / 2

    else:
        yilsonu_notu = donem2_mat[ogrenci]
        
    yilsonu_notlari.append(yilsonu_notu)

# %%
yilsonu_mat = pd.Series(yilsonu_notlari, index=donem2_mat.index)

print(yilsonu_mat)
# Out:
# Ali        82.5
# Deniz      86.0
# Aslı       89.5
# Burak      80.5
# Kerem      90.5
# Yasemin    94.0
# Derya      85.0
# Mert       83.0
# dtype: float64

# %% [markdown]
# 3) İndexlerinde "Osman", "Ozlem", "İnci", "Koray", "Melek" olan, columnlarında "Sınıf" , "Cinsiyet" , "Favori Ders" isimlerinde 3 column bulunan bir DF oluşturacaksınız. Osman'ın sınıfı 8 , cinsiyeti "E" , Favori Dersi "Fen"
# Ozlem'in sınıfı 11 , cinsiyeti "K" , Favori Dersi "Mat"
# İnci'nin sınıfı 5 , cinsiyeti "K" , Favori Dersi "Sosyal"
# Koray'ın sınıfı 9 , cinsiyeti "E" , Favori Dersi "Mat"
# Meleğin sınıfı 7 , cinsiyeti "K" , Favori Dersi "Ing"          Olacak şekilde bir df oluşturun.

# %%
my_idx3 = ["Osman", "Ozlem", "İnci", "Koray", "Melek"]
my_cols3 = ["Sınıf" , "Cinsiyet" , "Favori Ders"]

# %%
df3 = pd.DataFrame({"Sınıf": [8,11,5,9,7], "Cinsiyet": ["E","K","K","E","K"], "Favori Ders": ["Fen","Mat","Sosyal","Mat","Ing"]})

# %%
df3
# Out:
#    Sınıf Cinsiyet Favori Ders
# 0      8        E         Fen
# 1     11        K         Mat
# 2      5        K      Sosyal
# 3      9        E         Mat
# 4      7        K         Ing

# %% [markdown]
# 4) GitHubda bulunan "Advertising.csv" reklam datasını herhangi bir platformda DF olarak okuyun ve "df_adv" adında bir değişkene atayın. Ardından df_adv değişkeninin ilk 3 satırına, son 3 satırına , rastgele 3 satırına bakın.

# %%
df_adv = pd.read_csv("Advertising.csv")

# %%
df_adv.head(3)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
df_adv.tail(3)
# Out:
#         TV  radio  newspaper  sales
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df_adv.sample(3)
# Out:
#         TV  radio  newspaper  sales
# 186  139.5    2.1       26.6   10.3
# 9    199.8    2.6       21.2   10.6
# 64   131.1   42.8       28.9   18.0

# %% [markdown]
# 5) Elde ettiğiniz "df_adv" infosuna ve describe'ına bakın ve yorumlamaya çalışın.

# %%
df_adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df_adv.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# 6) df_adv içinden sadece "TV" sütununu seri olarak çekin.

# %%
df_adv[["TV"]]
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %% [markdown]
# 7) df_adv içinden "TV" ve "sales" sütununu çekin ve df_salesTV adında bir değişkene atayın.

# %%
df_salesTV = df_adv[["TV","sales"]]
df_salesTV
# Out:
#         TV  sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %% [markdown]
# 8) df_adv içindeki "TV" , "radio" , "newspaper" sütunlarındaki değerleri toplayarak "total_adv" adında yeni bir sütun oluşturun.

# %%
df_adv["total_adv"] = df_adv.sum(axis = 1)
df_adv
# Out:
#         TV  radio  newspaper  sales  total_adv
# 0    230.1   37.8       69.2   22.1      359.2
# 1     44.5   39.3       45.1   10.4      139.3
# 2     17.2   45.9       69.3    9.3      141.7
# 3    151.5   41.3       58.5   18.5      269.8
# 4    180.8   10.8       58.4   12.9      262.9
# ..     ...    ...        ...    ...        ...
# 195   38.2    3.7       13.8    7.6       63.3
# 196   94.2    4.9        8.1    9.7      116.9
# 197  177.0    9.3        6.4   12.8      205.5
# 198  283.6   42.0       66.2   25.5      417.3
# 199  232.1    8.6        8.7   13.4      262.8
#
# [200 rows x 5 columns]

# %% [markdown]
# 9) df_adv içindeki "sales" sütununun drop edilmiş halini ekrana yazdırın. (Kalıcı hale getirmeyin. Sadece ekrana bastırın)

# %%
df_adv.drop("sales",axis = 1)
# Out:
#         TV  radio  newspaper  total_adv
# 0    230.1   37.8       69.2      359.2
# 1     44.5   39.3       45.1      139.3
# 2     17.2   45.9       69.3      141.7
# 3    151.5   41.3       58.5      269.8
# 4    180.8   10.8       58.4      262.9
# ..     ...    ...        ...        ...
# 195   38.2    3.7       13.8       63.3
# 196   94.2    4.9        8.1      116.9
# 197  177.0    9.3        6.4      205.5
# 198  283.6   42.0       66.2      417.3
# 199  232.1    8.6        8.7      262.8
#
# [200 rows x 4 columns]

# %% [markdown]
# 10) df_adv içindeki son 50 index'i(satırı) çekin ve ekrana yazdırın.

# %%
df_adv[-50:]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 150  280.7   13.9       37.0   16.1      347.7
# 151  121.0    8.4       48.7   11.6      189.7
# 152  197.6   23.3       14.2   16.6      251.7
# 153  171.3   39.7       37.7   19.0      267.7
# 154  187.8   21.1        9.5   15.6      234.0
# 155    4.1   11.6        5.7    3.2       24.6
# 156   93.9   43.5       50.5   15.3      203.2
# 157  149.8    1.3       24.3   10.1      185.5
# 158   11.7   36.9       45.2    7.3      101.1
# 159  131.7   18.4       34.6   12.9      197.6
# 160  172.5   18.1       30.7   14.4      235.7
# 161   85.7   35.8       49.3   13.3      184.1
# 162  188.4   18.1       25.6   14.9      247.0
# 163  163.5   36.8        7.4   18.0      225.7
# 164  117.2   14.7        5.4   11.9      149.2
# 165  234.5    3.4       84.8   11.9      334.6
# 166   17.9   37.6       21.6    8.0       85.1
# 167  206.8    5.2       19.4   12.2      243.6
# 168  215.4   23.6       57.6   17.1      313.7
# 169  284.3   10.6        6.4   15.0      316.3
# 170   50.0   11.6       18.4    8.4       88.4
# 171  164.5   20.9       47.4   14.5      247.3
# 172   19.6   20.1       17.0    7.6       64.3
# 173  168.4    7.1       12.8   11.7      200.0
# 174  222.4    3.4       13.1   11.5      250.4
# 175  276.9   48.9       41.8   27.0      394.6
# 176  248.4   30.2       20.3   20.2      319.1
# 177  170.2    7.8       35.2   11.7      224.9
# 178  276.7    2.3       23.7   11.8      314.5
# 179  165.6   10.0       17.6   12.6      205.8
# 180  156.6    2.6        8.3   10.5      178.0
# 181  218.5    5.4       27.4   12.2      263.5
# 182   56.2    5.7       29.7    8.7      100.3
# 183  287.6   43.0       71.8   26.2      428.6
# 184  253.8   21.3       30.0   17.6      322.7
# 185  205.0   45.1       19.6   22.6      292.3
# 186  139.5    2.1       26.6   10.3      178.5
# 187  191.1   28.7       18.2   17.3      255.3
# 188  286.0   13.9        3.7   15.9      319.5
# 189   18.7   12.1       23.4    6.7       60.9
# 190   39.5   41.1        5.8   10.8       97.2
# 191   75.5   10.8        6.0    9.9      102.2
# 192   17.2    4.1       31.6    5.9       58.8
# 193  166.8   42.0        3.6   19.6      232.0
# 194  149.7   35.6        6.0   17.3      208.6
# 195   38.2    3.7       13.8    7.6       63.3
# 196   94.2    4.9        8.1    9.7      116.9
# 197  177.0    9.3        6.4   12.8      205.5
# 198  283.6   42.0       66.2   25.5      417.3
# 199  232.1    8.6        8.7   13.4      262.8

# %% [markdown]
# 11) df_adv içinde satışları 25'den fazla olanları getirin.

# %%
df_adv[df_adv["sales"] > 25]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 36   266.9   43.8        5.0   25.4      341.1
# 98   289.7   42.3       51.2   25.4      408.6
# 147  243.2   49.0       44.3   25.4      361.9
# 175  276.9   48.9       41.8   27.0      394.6
# 183  287.6   43.0       71.8   26.2      428.6
# 198  283.6   42.0       66.2   25.5      417.3

# %% [markdown]
# 12) df_adv içinde "TV" reklamlarına 250'den fazla VE "newspaper" reklamlarına 60'dan fazla harcama yapanları getirin.

# %%
df_adv[(df_adv["TV"] > 250) & (df_adv["newspaper"] > 60)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 93   250.9   36.5       72.3   22.2      381.9
# 101  296.4   36.3      100.9   23.8      457.4
# 183  287.6   43.0       71.8   26.2      428.6
# 198  283.6   42.0       66.2   25.5      417.3

# %% [markdown]
# 13) df_adv içinde "newspaper" reklam harcamaları 70'den fazla VEYA "radio" reklam harcamaları 50'den fazla olanları getirin.

# %%
df_adv[(df_adv["newspaper"] > 70) | (df_adv["radio"] > 50)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 5      8.7   48.9       75.0    7.2      139.8
# 16    67.8   36.6      114.0   12.5      230.9
# 75    16.9   43.7       89.4    8.7      158.7
# 88    88.3   25.5       73.4   12.9      200.1
# 93   250.9   36.5       72.3   22.2      381.9
# 101  296.4   36.3      100.9   23.8      457.4
# 118  125.7   36.9       79.2   15.9      257.7
# 124  229.5   32.3       74.2   19.7      355.7
# 141  193.7   35.4       75.6   19.2      323.9
# 165  234.5    3.4       84.8   11.9      334.6
# 183  287.6   43.0       71.8   26.2      428.6

# %% [markdown]
# 14) df_adv içinde "sales" ları 10 ile 15(10 ve 15 dahil) arasında olanları getirin.

# %%
df_adv[df_adv["sales"].between(10,15)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 1     44.5   39.3       45.1   10.4      139.3
# 4    180.8   10.8       58.4   12.9      262.9
# 6     57.5   32.8       23.5   11.8      125.6
# 7    120.2   19.6       11.6   13.2      164.6
# 9    199.8    2.6       21.2   10.6      234.2
# ..     ...    ...        ...    ...        ...
# 181  218.5    5.4       27.4   12.2      263.5
# 186  139.5    2.1       26.6   10.3      178.5
# 190   39.5   41.1        5.8   10.8       97.2
# 197  177.0    9.3        6.4   12.8      205.5
# 199  232.1    8.6        8.7   13.4      262.8
#
# [80 rows x 5 columns]

# %% [markdown]
# 15) df_adv içinde "sales" ları tam olarak 18.3 veya 14.0 veya 25.5 veya 21.7 veya 13.6 veya 6.9 olanları getirin.

# %%
df_adv[(df_adv["sales"] == 18.3) | (df_adv["sales"] == 14) | (df_adv["sales"] == 25.5) | (df_adv["sales"] == 21.17) | (df_adv["sales"] == 13.6) | (df_adv["sales"] == 6.9)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 63   102.7   29.6        8.4   14.0      154.7
# 70   199.1   30.6       38.7   18.3      286.7
# 76    27.5    1.6       20.7    6.9       56.7
# 83    68.4   44.5       35.6   13.6      162.1
# 198  283.6   42.0       66.2   25.5      417.3

# %% [markdown]
# 16) GitHubda bulunan "tips.csv" restoran datasını "df_tips" adıyla okuyun. Ardından ilk 5 satırına bakın.

# %%
df_tips = pd.read_csv("tips.csv")

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# 17) df_tips'in "CC Number" ve "Payment ID" column'larını kalıcı olarak düşürün.

# %%
df_tips.drop(["CC Number", "Payment ID"], axis = 1, inplace = True)
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name
# 0    Christy Cunningham
# 1        Douglas Tucker
# 2        Travis Walters
# 3      Nathaniel Harris
# 4          Tonya Carter
# ..                  ...
# 239       Michael Avila
# 240      Monica Sanders
# 241          Keith Wong
# 242        Dennis Dixon
# 243     Michelle Hardin
#
# [244 rows x 9 columns]

# %% [markdown]
# 18) df_tips'in "Payer Name" column'unu kalıcı olarak index yapın ve artık columndan düşürün.

# %%
df_tips.set_index("Payer Name", drop = True, inplace = True)
df_tips
# Out:
#                     total_bill   tip     sex smoker   day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No   Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No   Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No   Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No   Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No   Sun  Dinner     4
# ...                        ...   ...     ...    ...   ...     ...   ...
# Michael Avila            29.03  5.92    Male     No   Sat  Dinner     3
# Monica Sanders           27.18  2.00  Female    Yes   Sat  Dinner     2
# Keith Wong               22.67  2.00    Male    Yes   Sat  Dinner     2
# Dennis Dixon             17.82  1.75    Male     No   Sat  Dinner     2
# Michelle Hardin          18.78  3.00  Female     No  Thur  Dinner     2
#
#                     price_per_person
# Payer Name
# Christy Cunningham              8.49
# Douglas Tucker                  3.45
# Travis Walters                  7.00
# Nathaniel Harris               11.84
# Tonya Carter                    6.15
# ...                              ...
# Michael Avila                   9.68
# Monica Sanders                 13.59
# Keith Wong                     11.34
# Dennis Dixon                    8.91
# Michelle Hardin                 9.39
#
# [244 rows x 8 columns]

# %% [markdown]
# 19) df_tips içindeki kayıtlardan kişi sayısı 4 veya 4'den fazla olan siparişlerin kaç tane olduğunu bulun.(Sorguyu yazıp istediğimiz satırları getirdikten sonra basitçe len() fonksiyonunu kullanarak sayılarını bulabilirsiniz. Veya daha güzeli .shape[0] yaparak elde ettiğiniz sorguda kaç satır olduğunun sayısına ulaşabilirsiniz.)

# %%
df_tips[df_tips["size"] >= 4].shape[0]
# Out:
# 46

# %% [markdown]
# 20) df_tips içindeki Kişi sayısı 2 ya da 3 olan, sigara içen, erkek olan ve ödediği ücret 20 dolardan az olan kişi sayısını bulalım.

# %%
df_tips[df_tips["size"].isin([2,3])]
# Out:
#                     total_bill   tip     sex smoker   day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No   Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No   Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No   Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No   Sun  Dinner     2
# Kristopher Johnson        8.77  2.00    Male     No   Sun  Dinner     2
# ...                        ...   ...     ...    ...   ...     ...   ...
# Michael Avila            29.03  5.92    Male     No   Sat  Dinner     3
# Monica Sanders           27.18  2.00  Female    Yes   Sat  Dinner     2
# Keith Wong               22.67  2.00    Male    Yes   Sat  Dinner     2
# Dennis Dixon             17.82  1.75    Male     No   Sat  Dinner     2
# Michelle Hardin          18.78  3.00  Female     No  Thur  Dinner     2
#
#                     price_per_person
# Payer Name
# Christy Cunningham              8.49
# Douglas Tucker                  3.45
# Travis Walters                  7.00
# Nathaniel Harris               11.84
# Kristopher Johnson              4.38
# ...                              ...
# Michael Avila                   9.68
# Monica Sanders                 13.59
# Keith Wong                     11.34
# Dennis Dixon                    8.91
# Michelle Hardin                 9.39
#
# [194 rows x 8 columns]
